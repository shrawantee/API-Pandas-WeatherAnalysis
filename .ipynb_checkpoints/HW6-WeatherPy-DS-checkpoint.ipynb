# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
import json

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#Random selection of latitude and longitude 

lat = np.random.choice(range(-90,90),2000)
lng = np.random.choice(range(-180,180),2000)

lat_lng = pd.DataFrame({"Lat":lat,"Long":lng})        

#print(len(lat_lng)
lat_lng.head()
# Out:
#    Lat  Long
# 0   31    39
# 1  -88    99
# 2   74    96
# 3  -50   -42
# 4   59     3

# %%
#Use citipy to merge them to nearest city
#Create new columns for the city name: 
lat_lng["city_name"] = ""
lat_lng["country"] = ""
#LatLon.head()
for index,row in lat_lng.iterrows():
    city = citipy.nearest_city(row["Lat"],row["Long"])
    lat_lng.set_value(index,"city_name",city.city_name)
    lat_lng.set_value(index,"country",city.country_code)

print(f"The length of the dataframe is: {len(lat_lng)}")
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# The length of the dataframe is: 2000

# %%
#Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude 

#Clean it for missing values
nr_lat_lng = lat_lng.dropna()
print(f"The length of the cleaned dataframe is:{len(nr_lat_lng)}")


nr_lat_lng = nr_lat_lng.drop_duplicates()
print(f"The length of the dataframe after dropping the duplicates is: {len(nr_lat_lng)}")

# Sample for "at least" 500 cities 
sample = nr_lat_lng.sample(750)
sample =sample.reset_index()
sample = sample.iloc[:,[1,2,3,4]]
print(f"The length of the sample is: {len(sample)}")

sample.head()
# Out:
# The length of the cleaned dataframe is:2000
# The length of the dataframe after dropping the duplicates is: 1977
# The length of the sample is: 750
#    Lat  Long     city_name country
# 0  -77  -108  punta arenas      cl
# 1  -47  -148       mataura      pf
# 2   49  -162        bethel      us
# 3   76    66       amderma      ru
# 4   79   -75       qaanaaq      gl

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
url = "http://api.openweathermap.org/data/2.5/weather?"
params = { "appid":"7bbe5eb80fc0e9d5e7535b057e554fd5","units":"imperial" }

#Print the base url 

print("-----------------------------------------")
print("Beginning Data Retrieval")
print("-----------------------------------------\n")

for index,row in sample.iterrows():
    params["q"] =f'{row["city_name"]},{row["country"]}'
    print(f"Processing Record {index+1} of {len(sample)}")
    response = requests.get(url,params)
    print(response.url)
    formatted_response = response.json()
    sample.set_value(index,"Latitude",formatted_response.get("coord",{}).get("lat"))
    sample.set_value(index,"Longitude",formatted_response.get("coord",{}).get("lon"))
    sample.set_value(index,"Temperature",formatted_response.get("main",{}).get("temp"))
    sample.set_value(index,"Max Temperature",formatted_response.get("main",{}).get("temp_max"))
    sample.set_value(index,"Humidity",formatted_response.get("main",{}).get("humidity"))
    sample.set_value(index,"Wind speed",formatted_response.get("wind",{}).get("speed"))
    sample.set_value(index,"Cloudiness",formatted_response.get("clouds",{}).get("all"))
    sample.set_value(index,"Date",formatted_response.get("dt"))

print("-----------------------------------------")
print("Data Retrieval Complete")
print("-----------------------------------------")
# Out:
# -----------------------------------------
# Beginning Data Retrieval
# -----------------------------------------
#
# Processing Record 1 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 2 of 750
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 3 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bethel%2Cus
# Processing Record 4 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=amderma%2Cru
# Processing Record 5 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=qaanaaq%2Cgl
# Processing Record 6 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tuatapere%2Cnz
# Processing Record 7 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bethel%2Cus
# Processing Record 8 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 9 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=yellowknife%2Cca
# Processing Record 10 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 11 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vestmannaeyjar%2Cis
# Processing Record 12 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=alofi%2Cnu
# Processing Record 13 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=torbay%2Cca
# Processing Record 14 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 15 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hobart%2Cau
# Processing Record 16 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bredasdorp%2Cza
# Processing Record 17 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kidal%2Cml
# Processing Record 18 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=san+patricio%2Cmx
# Processing Record 19 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jamestown%2Csh
# Processing Record 20 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sentyabrskiy%2Cru
# Processing Record 21 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=peniche%2Cpt
# Processing Record 22 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=saint-philippe%2Cre
# Processing Record 23 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kodiak%2Cus
# Processing Record 24 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=qaqortoq%2Cgl
# Processing Record 25 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kulhudhuffushi%2Cmv
# Processing Record 26 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 27 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=springbok%2Cza
# Processing Record 28 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=selkirk%2Cca
# Processing Record 29 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 30 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sambava%2Cmg
# Processing Record 31 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tuatapere%2Cnz
# Processing Record 32 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mandalgovi%2Cmn
# Processing Record 33 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 34 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 35 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jamestown%2Csh
# Processing Record 36 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=posadas%2Car
# Processing Record 37 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=faanui%2Cpf
# Processing Record 38 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 39 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=whitehorse%2Cca
# Processing Record 40 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=longyearbyen%2Csj
# Processing Record 41 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=talnakh%2Cru
# Processing Record 42 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 43 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kinsale%2Cie
# Processing Record 44 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=roebourne%2Cau
# Processing Record 45 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=atambua%2Cid
# Processing Record 46 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=avarua%2Cck
# Processing Record 47 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sao+filipe%2Ccv
# Processing Record 48 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=barrow%2Cus
# Processing Record 49 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=butaritari%2Cki
# Processing Record 50 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ahuimanu%2Cus
# Processing Record 51 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 52 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port-cartier%2Cca
# Processing Record 53 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=barrhead%2Cca
# Processing Record 54 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=witbank%2Cza
# Processing Record 55 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 56 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=barentsburg%2Csj
# Processing Record 57 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thompson%2Cca
# Processing Record 58 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 59 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 60 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thompson%2Cca
# Processing Record 61 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tyup%2Ckg
# Processing Record 62 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hobart%2Cau
# Processing Record 63 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 64 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sao+miguel+do+araguaia%2Cbr
# Processing Record 65 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bethel%2Cus
# Processing Record 66 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 67 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nome%2Cus
# Processing Record 68 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sao+joao+da+barra%2Cbr
# Processing Record 69 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bulgan%2Cmn
# Processing Record 70 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 71 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vaini%2Cto
# Processing Record 72 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+hardy%2Cca
# Processing Record 73 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bredasdorp%2Cza
# Processing Record 74 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 75 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=fourmies%2Cfr
# Processing Record 76 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=illoqqortoormiut%2Cgl
# Processing Record 77 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 78 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=avarua%2Cck
# Processing Record 79 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tuktoyaktuk%2Cca
# Processing Record 80 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kaiu%2Cee
# Processing Record 81 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ambon%2Cid
# Processing Record 82 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=general+bravo%2Cmx
# Processing Record 83 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=geraldton%2Cau
# Processing Record 84 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kailua%2Cus
# Processing Record 85 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=diego+de+almagro%2Ccl
# Processing Record 86 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tairua%2Cnz
# Processing Record 87 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=leningradskiy%2Cru
# Processing Record 88 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taltal%2Ccl
# Processing Record 89 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hithadhoo%2Cmv
# Processing Record 90 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 91 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=beauceville%2Cca
# Processing Record 92 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ugoofaaru%2Cmv
# Processing Record 93 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=upernavik%2Cgl
# Processing Record 94 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=loreto%2Cmx
# Processing Record 95 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vaini%2Cto
# Processing Record 96 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+alfred%2Cza
# Processing Record 97 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=husavik%2Cis
# Processing Record 98 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nuuk%2Cgl
# Processing Record 99 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=palmer%2Cus
# Processing Record 100 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=north+bend%2Cus
# Processing Record 101 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 102 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=fort+saint+john%2Cca
# Processing Record 103 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=airai%2Cpw
# Processing Record 104 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 105 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rundu%2Cna
# Processing Record 106 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+alfred%2Cza
# Processing Record 107 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tuktoyaktuk%2Cca
# Processing Record 108 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vaini%2Cto
# Processing Record 109 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+alfred%2Cza
# Processing Record 110 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tuktoyaktuk%2Cca
# Processing Record 111 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ancud%2Ccl
# Processing Record 112 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=abramovka%2Cru
# Processing Record 113 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 114 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mar+del+plata%2Car
# Processing Record 115 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 116 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 117 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=yellowknife%2Cca
# Processing Record 118 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jamestown%2Csh
# Processing Record 119 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bengkulu%2Cid
# Processing Record 120 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=qaanaaq%2Cgl
# Processing Record 121 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 122 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 123 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+hardy%2Cca
# Processing Record 124 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=illoqqortoormiut%2Cgl
# Processing Record 125 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=saint-philippe%2Cre
# Processing Record 126 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ginir%2Cet
# Processing Record 127 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 128 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mabaruma%2Cgy
# Processing Record 129 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mys+shmidta%2Cru
# Processing Record 130 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 131 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=avarua%2Cck
# Processing Record 132 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=albany%2Cau
# Processing Record 133 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=severo-kurilsk%2Cru
# Processing Record 134 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ambovombe%2Cmg
# Processing Record 135 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=grand+river+south+east%2Cmu
# Processing Record 136 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=longyearbyen%2Csj
# Processing Record 137 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mayumba%2Cga
# Processing Record 138 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=geraldton%2Cau
# Processing Record 139 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 140 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hermanus%2Cza
# Processing Record 141 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jibuti%2Cdj
# Processing Record 142 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 143 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kodiak%2Cus
# Processing Record 144 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ngukurr%2Cau
# Processing Record 145 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bahia+blanca%2Car
# Processing Record 146 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 147 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+baquerizo+moreno%2Cec
# Processing Record 148 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ostrovnoy%2Cru
# Processing Record 149 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=brae%2Cgb
# Processing Record 150 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=peniche%2Cpt
# Processing Record 151 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 152 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=santa+maria%2Ccv
# Processing Record 153 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=andros+town%2Cbs
# Processing Record 154 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 155 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=resistencia%2Car
# Processing Record 156 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=opelousas%2Cus
# Processing Record 157 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=inuvik%2Cca
# Processing Record 158 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 159 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=qaanaaq%2Cgl
# Processing Record 160 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 161 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=elizabeth+city%2Cus
# Processing Record 162 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thompson%2Cca
# Processing Record 163 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=haines+junction%2Cca
# Processing Record 164 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=castro%2Ccl
# Processing Record 165 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nicoya%2Ccr
# Processing Record 166 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=butaritari%2Cki
# Processing Record 167 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=arraial+do+cabo%2Cbr
# Processing Record 168 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 169 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 170 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=victoria%2Csc
# Processing Record 171 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tiksi%2Cru
# Processing Record 172 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=myitkyina%2Cmm
# Processing Record 173 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=khatanga%2Cru
# Processing Record 174 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 175 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mogadishu%2Cso
# Processing Record 176 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 177 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=qaanaaq%2Cgl
# Processing Record 178 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=saint+anthony%2Cca
# Processing Record 179 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=esperance%2Cau
# Processing Record 180 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 181 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=osoyoos%2Cca
# Processing Record 182 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kangaatsiaq%2Cgl
# Processing Record 183 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=yellowknife%2Cca
# Processing Record 184 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=katakwi%2Cug
# Processing Record 185 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 186 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 187 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=panama+city%2Cus
# Processing Record 188 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nizhniy+kuranakh%2Cru
# Processing Record 189 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mount+gambier%2Cau
# Processing Record 190 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vaitupu%2Cwf
# Processing Record 191 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=airai%2Cpw
# Processing Record 192 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=atuona%2Cpf
# Processing Record 193 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=alekseyevsk%2Cru
# Processing Record 194 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ketchikan%2Cus
# Processing Record 195 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=butaritari%2Cki
# Processing Record 196 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=shenkursk%2Cru
# Processing Record 197 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nikolskoye%2Cru
# Processing Record 198 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nikolskoye%2Cru
# Processing Record 199 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kathmandu%2Cnp
# Processing Record 200 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 201 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 202 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=albany%2Cau
# Processing Record 203 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=talaya%2Cru
# Processing Record 204 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 205 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bredasdorp%2Cza
# Processing Record 206 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=illoqqortoormiut%2Cgl
# Processing Record 207 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 208 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=illoqqortoormiut%2Cgl
# Processing Record 209 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 210 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 211 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=yellowknife%2Cca
# Processing Record 212 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nouadhibou%2Cmr
# Processing Record 213 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 214 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 215 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=katsuura%2Cjp
# Processing Record 216 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=coquimbo%2Ccl
# Processing Record 217 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kwekwe%2Czw
# Processing Record 218 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 219 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=naze%2Cjp
# Processing Record 220 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=teya%2Cru
# Processing Record 221 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ontario%2Cus
# Processing Record 222 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tasiilaq%2Cgl
# Processing Record 223 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 224 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hermanus%2Cza
# Processing Record 225 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 226 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kamenka%2Cru
# Processing Record 227 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=gat%2Cly
# Processing Record 228 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=fairbanks%2Cus
# Processing Record 229 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+elizabeth%2Cza
# Processing Record 230 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=butaritari%2Cki
# Processing Record 231 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lerwick%2Cgb
# Processing Record 232 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bredasdorp%2Cza
# Processing Record 233 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 234 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cidreira%2Cbr
# Processing Record 235 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=porto+walter%2Cbr
# Processing Record 236 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mutsamudu%2Ckm
# Processing Record 237 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=moree%2Cau
# Processing Record 238 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=santa+fe%2Car
# Processing Record 239 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=castro%2Ccl
# Processing Record 240 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vedeno%2Cru
# Processing Record 241 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jamestown%2Csh
# Processing Record 242 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nyurba%2Cru
# Processing Record 243 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=saint+george%2Cbm
# Processing Record 244 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cabot%2Cus
# Processing Record 245 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 246 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=zaraza%2Cve
# Processing Record 247 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 248 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 249 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nanortalik%2Cgl
# Processing Record 250 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 251 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 252 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lahij%2Cye
# Processing Record 253 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=castro%2Ccl
# Processing Record 254 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 255 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=namatanai%2Cpg
# Processing Record 256 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=vangaindrano%2Cmg
# Processing Record 257 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 258 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=new+norfolk%2Cau
# Processing Record 259 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 260 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=illoqqortoormiut%2Cgl
# Processing Record 261 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=monkey+bay%2Cmw
# Processing Record 262 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ilulissat%2Cgl
# Processing Record 263 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=norman+wells%2Cca
# Processing Record 264 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 265 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=benghazi%2Cly
# Processing Record 266 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=adet%2Cet
# Processing Record 267 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sayyan%2Cye
# Processing Record 268 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 269 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mar+del+plata%2Car
# Processing Record 270 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=namatanai%2Cpg
# Processing Record 271 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=pangai%2Cto
# Processing Record 272 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=attawapiskat%2Cca
# Processing Record 273 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jamestown%2Csh
# Processing Record 274 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sibu%2Cmy
# Processing Record 275 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 276 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tuatapere%2Cnz
# Processing Record 277 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hobart%2Cau
# Processing Record 278 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thompson%2Cca
# Processing Record 279 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kant%2Ckg
# Processing Record 280 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hostotipaquillo%2Cmx
# Processing Record 281 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=corner+brook%2Cca
# Processing Record 282 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ginir%2Cet
# Processing Record 283 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=flinders%2Cau
# Processing Record 284 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=jiuquan%2Ccn
# Processing Record 285 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=oranjemund%2Cna
# Processing Record 286 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sturgis%2Cus
# Processing Record 287 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=terrasini%2Cit
# Processing Record 288 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 289 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hermanus%2Cza
# Processing Record 290 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sayyan%2Cye
# Processing Record 291 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=saskylakh%2Cru
# Processing Record 292 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 293 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kodiak%2Cus
# Processing Record 294 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sur%2Com
# Processing Record 295 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=illoqqortoormiut%2Cgl
# Processing Record 296 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+lincoln%2Cau
# Processing Record 297 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 298 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mar+del+plata%2Car
# Processing Record 299 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=novyy+urengoy%2Cru
# Processing Record 300 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kaitangata%2Cnz
# Processing Record 301 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bud%2Cno
# Processing Record 302 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=harer%2Cet
# Processing Record 303 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 304 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puerto+ayora%2Cec
# Processing Record 305 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sorong%2Cid
# Processing Record 306 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=qaanaaq%2Cgl
# Processing Record 307 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 308 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hermanus%2Cza
# Processing Record 309 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 310 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 311 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mar+del+plata%2Car
# Processing Record 312 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ambulu%2Cid
# Processing Record 313 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=longyearbyen%2Csj
# Processing Record 314 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ancud%2Ccl
# Processing Record 315 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cherskiy%2Cru
# Processing Record 316 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=atuona%2Cpf
# Processing Record 317 of 750
# ...
# Processing Record 643 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thompson%2Cca
# Processing Record 644 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 645 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kendari%2Cid
# Processing Record 646 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tiksi%2Cru
# Processing Record 647 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lolua%2Ctv
# Processing Record 648 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kaeo%2Cnz
# Processing Record 649 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=atuona%2Cpf
# Processing Record 650 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=carutapera%2Cbr
# Processing Record 651 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sistranda%2Cno
# Processing Record 652 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tura%2Cru
# Processing Record 653 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 654 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 655 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rocha%2Cuy
# Processing Record 656 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=key+west%2Cus
# Processing Record 657 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=isangel%2Cvu
# Processing Record 658 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 659 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=camopi%2Cgf
# Processing Record 660 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=den+helder%2Cnl
# Processing Record 661 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cidreira%2Cbr
# Processing Record 662 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thatta%2Cpk
# Processing Record 663 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hilo%2Cus
# Processing Record 664 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hermanus%2Cza
# Processing Record 665 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=goderich%2Csl
# Processing Record 666 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kapaa%2Cus
# Processing Record 667 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hobart%2Cau
# Processing Record 668 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=petatlan%2Cmx
# Processing Record 669 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lebu%2Ccl
# Processing Record 670 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=rikitea%2Cpf
# Processing Record 671 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=umzimvubu%2Cza
# Processing Record 672 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ugoofaaru%2Cmv
# Processing Record 673 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 674 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bluff%2Cnz
# Processing Record 675 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kingaroy%2Cau
# Processing Record 676 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=atuona%2Cpf
# Processing Record 677 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=leningradskiy%2Cru
# Processing Record 678 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mogadishu%2Cso
# Processing Record 679 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sioux+lookout%2Cca
# Processing Record 680 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 681 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=zachagansk%2Ckz
# Processing Record 682 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 683 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bulaevo%2Ckz
# Processing Record 684 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=victoria%2Csc
# Processing Record 685 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=aleksandrov+gay%2Cru
# Processing Record 686 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=pacific+grove%2Cus
# Processing Record 687 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=neustadt%2Cde
# Processing Record 688 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 689 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 690 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=saint-augustin%2Cca
# Processing Record 691 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=labutta%2Cmm
# Processing Record 692 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=butaritari%2Cki
# Processing Record 693 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lebu%2Ccl
# Processing Record 694 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 695 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=narsaq%2Cgl
# Processing Record 696 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 697 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mecca%2Csa
# Processing Record 698 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=san+patricio%2Cmx
# Processing Record 699 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=riaba%2Cgq
# Processing Record 700 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lebu%2Ccl
# Processing Record 701 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=sambava%2Cmg
# Processing Record 702 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=san+miguel%2Cbo
# Processing Record 703 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=punta+arenas%2Ccl
# Processing Record 704 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mattru%2Csl
# Processing Record 705 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ilhabela%2Cbr
# Processing Record 706 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=grand+river+south+east%2Cmu
# Processing Record 707 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=gurskoye%2Cru
# Processing Record 708 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=albany%2Cau
# Processing Record 709 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+alfred%2Cza
# Processing Record 710 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=georgetown%2Csh
# Processing Record 711 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mahebourg%2Cmu
# Processing Record 712 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 713 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=yellowknife%2Cca
# Processing Record 714 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=thompson%2Cca
# Processing Record 715 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bredasdorp%2Cza
# Processing Record 716 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=puri%2Cin
# Processing Record 717 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 718 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=khatanga%2Cru
# Processing Record 719 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=belushya+guba%2Cru
# Processing Record 720 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cape+town%2Cza
# Processing Record 721 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cape+town%2Cza
# Processing Record 722 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=esperance%2Cau
# Processing Record 723 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bagdarin%2Cru
# Processing Record 724 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=ushuaia%2Car
# Processing Record 725 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=archidona%2Cec
# Processing Record 726 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=nizwa%2Com
# Processing Record 727 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=stepnogorsk%2Ckz
# Processing Record 728 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=port+alfred%2Cza
# Processing Record 729 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lloydminster%2Cca
# Processing Record 730 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=barrow%2Cus
# Processing Record 731 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 732 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=bargal%2Cso
# Processing Record 733 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=tasiilaq%2Cgl
# Processing Record 734 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=huron%2Cus
# Processing Record 735 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=arraial+do+cabo%2Cbr
# Processing Record 736 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cape+town%2Cza
# Processing Record 737 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=taolanaro%2Cmg
# Processing Record 738 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=busselton%2Cau
# Processing Record 739 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lagunas%2Cpe
# Processing Record 740 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=cape+town%2Cza
# Processing Record 741 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=lubango%2Cao
# Processing Record 742 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=kaitangata%2Cnz
# Processing Record 743 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=castro%2Ccl
# Processing Record 744 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=henties+bay%2Cna
# Processing Record 745 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=fitionesti%2Cro
# Processing Record 746 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hobart%2Cau
# Processing Record 747 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=luderitz%2Cna
# Processing Record 748 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=mataura%2Cpf
# Processing Record 749 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=hermanus%2Cza
# Processing Record 750 of 750
# http://api.openweathermap.org/data/2.5/weather?appid=7bbe5eb80fc0e9d5e7535b057e554fd5&units=imperial&q=attawapiskat%2Cca
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %%
#Clean the retrieved data
sample = sample.dropna()
#Create a dataframe
weatherPy = pd.DataFrame({"city_name":sample["city_name"],
                          "country":sample["country"],
                         "cloudiness":sample["Cloudiness"],
                         "humidity":sample["Humidity"],
                         "lat":sample["Latitude"],
                         "lng":sample["Longitude"],
                        "temperature":sample["Temperature"],
                          "max_temp":sample["Max Temperature"],
                         "wind speed":sample["Wind speed"],
                          "date":sample["Date"]})

weatherPy["date"]=weatherPy["date"].astype('int')
# Save as CSV
weatherPy.to_csv("weatherPy.csv")
weatherPy.count()
# Out:
# city_name      651
# country        651
# cloudiness     651
# humidity       651
# lat            651
# lng            651
# temperature    651
# max_temp       651
# wind speed     651
# date           651
# dtype: int64

# %%
weatherPy.describe()
# Out:
#        cloudiness    humidity         lat         lng  temperature  \
# count  651.000000  651.000000  651.000000  651.000000   651.000000
# mean    44.327189   81.016897    4.448710   -8.659462    61.724009
# std     34.592603   18.116580   41.178256  102.851998    15.881617
# min      0.000000   14.000000  -54.810000 -175.200000    32.050000
# 25%     12.000000   69.000000  -33.640000  -90.350000    48.790000
# 50%     40.000000   87.000000   -2.760000  -17.340000    60.940000
# 75%     75.000000   96.500000   42.865000   73.965000    74.935000
# max    100.000000  100.000000   78.220000  179.320000    96.310000
#
#          max_temp  wind speed          date
# count  651.000000  651.000000  6.510000e+02
# mean    62.051674    9.057527  1.533670e+09
# std     16.252271    6.154549  1.498153e+03
# min     32.050000    0.040000  1.533667e+09
# 25%     48.790000    4.700000  1.533668e+09
# 50%     61.120000    6.980000  1.533671e+09
# 75%     75.160000   12.910000  1.533672e+09
# max    107.600000   31.140000  1.533672e+09

# %%
#Convert the CSV into a dataframe for the plotting purposes
weatherPy_plt = pd.read_csv("weatherPy.csv")
weatherPy_plt.head()
# Out:
#    Unnamed: 0     city_name country  cloudiness  humidity    lat     lng  \
# 0           0  punta arenas      cl        90.0      93.0 -53.16  -70.91
# 1           2        bethel      us        90.0      93.0  60.79 -161.76
# 2           4       qaanaaq      gl        64.0      87.0  77.48  -69.36
# 3           5     tuatapere      nz        88.0     100.0 -46.13  167.69
# 4           6        bethel      us        90.0      93.0  60.79 -161.76
#
#    temperature  max_temp  wind speed        date
# 0        35.60     35.60        5.82  1533668400
# 1        51.80     51.80        6.93  1533668460
# 2        39.25     39.25        2.95  1533671478
# 3        42.58     42.58        4.63  1533671478
# 4        51.80     51.80        6.93  1533668460

# %%
#Analysis: Maximum Temperature (F) vs. Latitude
fig, ax = plt.subplots(figsize=(10, 9))
ax.scatter(weatherPy_plt['lat'], weatherPy_plt['max_temp'], c='blue',alpha=.6, linewidth=1, edgecolor='black')

#Set x and y limits, title, labels
ax.set_xlim(-90, 90)
ax.set_ylim(min(weatherPy_plt['max_temp'])-20, max(weatherPy_plt['max_temp'])+20)
ax.set_xlabel("City Latitude")
ax.set_ylabel("Maximum Temperature (F)")
ax.set_title("City Latitude vs. Maximum Temperature (8/7/2018)")

# Save png images for each scatter plot.
plt.savefig("Latitude vs. Maximum_Temperature.png")
plt.grid()
plt.show()

# %%
 #Analysis 2: Humidity (%) vs. Latitude
fig, ax = plt.subplots(figsize=(10, 9))
ax.scatter(weatherPy_plt['lat'], weatherPy_plt['humidity'], c='blue',alpha=.6, linewidth=1, edgecolor='black')

#Set x and y limits, title, labels
ax.set_xlim(-90, 90)
ax.set_ylim(min(weatherPy_plt['humidity'])-20, max(weatherPy_plt['humidity'])+20)
ax.set_xlabel("City Latitude")
ax.set_ylabel("Humidity (%) ")
ax.set_title("City Latitude vs. Humidity (%) (8/7/2018)")

# Save png images for each scatter plot.
plt.savefig("Latitude vs. Humidity (%).png")
plt.grid()
plt.show()

# %%
#Analysis 3. Cloudiness (%) vs. Latitude
fig, ax = plt.subplots(figsize=(10, 9))
ax.scatter(weatherPy_plt['lat'], weatherPy_plt['cloudiness'], c='blue',alpha=.6, linewidth=1, edgecolor='black')

#Set x and y limits, title, labels
ax.set_xlim(-90, 90)
ax.set_ylim(min(weatherPy_plt['cloudiness'])-20, max(weatherPy_plt['cloudiness'])+20)
ax.set_xlabel("City Latitude")
ax.set_ylabel("Cloudiness (%) ")
ax.set_title("City Latitude vs. Cloudiness (%) (8/7/2018)")

# Save png images for each scatter plot.
plt.savefig("Latitude vs. Cloudiness (%).png")
plt.grid()
plt.show()

# %%
#Analysis 4. Wind Speed (mph) vs. Latitude

fig, ax = plt.subplots(figsize=(10, 9))
ax.scatter(weatherPy_plt['lat'], weatherPy_plt['wind speed'], c='blue',alpha=.6, linewidth=1, edgecolor='black')

#Set x and y limits, title, labels
ax.set_xlim(-90, 90)
ax.set_ylim(min(weatherPy_plt['wind speed'])-20, max(weatherPy_plt['wind speed'])+20)
ax.set_xlabel("City Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (mph) (8/7/2018)")

# Save png images for each scatter plot.
plt.savefig("Latitude vs. Wind Speed (mph).png")
plt.grid()
plt.show()

# %% [markdown]
# #Observations:
#
# #1. Latitude vs. Maximum_Temperature: As one moves away from the equator on either directions (northern or the southern hemisphere, the temperature as of today (8/7/2018) changes from highto low. What is striking is that the highest temperatures are NOT at the equator. The max temperature of 107.6 is recorded a little below 40 degree latitude N. The highest recorded temperatures and cools off as one moves towards the poles.
# #2. In terms of humidity, extremely hot and cooler places tend to be humid. Cooler palces below 40F seem be a very humid. This is true for places that record very temperatures too (for example between latidues of 20 to 40 degree N, the humidity can be either very high (100%) or relatively low humidity of less than 20%.
# #3. Wind speed is on an average close to 9 mph (pretty calm) compared to the highest windspeed of about 31 mph. As we move away from the equator the wind speed remains closely tied to the 0 to 10 mph.
